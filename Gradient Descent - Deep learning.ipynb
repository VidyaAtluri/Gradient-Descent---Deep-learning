# %%
# DO NOT edit this cell!  
# You must use this cost function and its derivative as-is

# cost at particular value of w1
def calc_J(w1):
    return (5.5*w1*w1 - 1463*w1 + 100812.5)

# slope at particular value of w1
def calc_dJ_dw1(w1):
    return (11*w1 - 1463)

# %%
# First, complete coding Steps 1 through 5 in this cell.
# Then, run this cell for each of the four scenarios below,
# and log your responses for each scenario run in the next cell (Step 6)
alpha=0.08; niterations = 25; w1 = 60 # Scenario 1
# alpha=0.05; niterations = 25; w1 = 60 # Scenario 2
# alpha=0.15; niterations = 25; w1 = 60 # Scenario 3
# alpha=0.19; niterations = 25; w1 = 60 # Scenario 4

# Step 1: calculate current value of J at current value of w1
J = calc_J(60)
print("value of J:")
print(J)


# Step 2: print w1 (rounded to 2 decimal places) and J (rounded to 2 decimal places)
print("value of w1:")
print(round(w1,2))
print("value of J:")
print(round(J,2))


# run gradient descent for niterations
for i in range(niterations):
    
    # Step 3: calculate new value of w1
    w1 = w1 - alpha * calc_dJ_dw1(w1)
    
    
    # Step 4: calculate new value of J at new w1
    J = calc_J(w1)
    
    
    # Step 5: print w1 (rounded to 2 decimal places) and J (rounded to 2 decimal places)
#     print(f"Iteration {i+1}: w1={w1:.2f}, J={J:.2f}")
    print("Iteration {}, w1={}, J={}".format(i+1,round(w1,2),round(J,2)))
# Out:
# value of J:
# 32832.5
# value of w1:
# 60
# value of J:
# 32832.5
# Iteration 1, w1=124.24, J=3945.06
# Iteration 2, w1=131.95, J=3529.08
# Iteration 3, w1=132.87, J=3523.09
# Iteration 4, w1=132.98, J=3523.0
# Iteration 5, w1=133.0, J=3523.0
# Iteration 6, w1=133.0, J=3523.0
# Iteration 7, w1=133.0, J=3523.0
# Iteration 8, w1=133.0, J=3523.0
# Iteration 9, w1=133.0, J=3523.0
# Iteration 10, w1=133.0, J=3523.0
# Iteration 11, w1=133.0, J=3523.0
# Iteration 12, w1=133.0, J=3523.0
# Iteration 13, w1=133.0, J=3523.0
# Iteration 14, w1=133.0, J=3523.0
# Iteration 15, w1=133.0, J=3523.0
# Iteration 16, w1=133.0, J=3523.0
# Iteration 17, w1=133.0, J=3523.0
# Iteration 18, w1=133.0, J=3523.0
# Iteration 19, w1=133.0, J=3523.0
# Iteration 20, w1=133.0, J=3523.0
# Iteration 21, w1=133.0, J=3523.0
# Iteration 22, w1=133.0, J=3523.0
# Iteration 23, w1=133.0, J=3523.0
# Iteration 24, w1=133.0, J=3523.0
# Iteration 25, w1=133.0, J=3523.0

# %%
# First, complete coding Steps 1 through 5 in this cell.
# Then, run this cell for each of the four scenarios below,
# and log your responses for each scenario run in the next cell (Step 6)
# alpha=0.08; niterations = 25; w1 = 60 # Scenario 1
alpha=0.05; niterations = 25; w1 = 60 # Scenario 2
# alpha=0.15; niterations = 25; w1 = 60 # Scenario 3
# alpha=0.19; niterations = 25; w1 = 60 # Scenario 4

# Step 1: calculate current value of J at current value of w1
J = calc_J(60)
print("value of J:")
print(J)


# Step 2: print w1 (rounded to 2 decimal places) and J (rounded to 2 decimal places)
print("value of w1:")
print(round(w1,2))
print("value of J:")
print(round(J,2))


# run gradient descent for niterations
for i in range(niterations):
    
    # Step 3: calculate new value of w1
    w1 = w1 - alpha * calc_dJ_dw1(w1)
    
    
    # Step 4: calculate new value of J at new w1
    J = calc_J(w1)
    
    
    # Step 5: print w1 (rounded to 2 decimal places) and J (rounded to 2 decimal places)
#     print(f"Iteration {i+1}: w1={w1:.2f}, J={J:.2f}")
    print("Iteration {}, w1={}, J={}".format(i+1,round(w1,2),round(J,2)))
# Out:
# value of J:
# 32832.5
# value of w1:
# 60
# value of J:
# 32832.5
# Iteration 1, w1=100.15, J=9458.17
# Iteration 2, w1=118.22, J=4724.87
# Iteration 3, w1=126.35, J=3766.38
# Iteration 4, w1=130.01, J=3572.28
# Iteration 5, w1=131.65, J=3532.98
# Iteration 6, w1=132.39, J=3525.02
# Iteration 7, w1=132.73, J=3523.41
# Iteration 8, w1=132.88, J=3523.08
# Iteration 9, w1=132.94, J=3523.02
# Iteration 10, w1=132.98, J=3523.0
# Iteration 11, w1=132.99, J=3523.0
# Iteration 12, w1=132.99, J=3523.0
# Iteration 13, w1=133.0, J=3523.0
# Iteration 14, w1=133.0, J=3523.0
# Iteration 15, w1=133.0, J=3523.0
# Iteration 16, w1=133.0, J=3523.0
# Iteration 17, w1=133.0, J=3523.0
# Iteration 18, w1=133.0, J=3523.0
# Iteration 19, w1=133.0, J=3523.0
# Iteration 20, w1=133.0, J=3523.0
# Iteration 21, w1=133.0, J=3523.0
# Iteration 22, w1=133.0, J=3523.0
# Iteration 23, w1=133.0, J=3523.0
# Iteration 24, w1=133.0, J=3523.0
# Iteration 25, w1=133.0, J=3523.0

# %%
# First, complete coding Steps 1 through 5 in this cell.
# Then, run this cell for each of the four scenarios below,
# and log your responses for each scenario run in the next cell (Step 6)
# alpha=0.08; niterations = 25; w1 = 60 # Scenario 1
# alpha=0.05; niterations = 25; w1 = 60 # Scenario 2
alpha=0.15; niterations = 25; w1 = 60 # Scenario 3
# alpha=0.19; niterations = 25; w1 = 60 # Scenario 4

# Step 1: calculate current value of J at current value of w1
J = calc_J(60)
print("value of J:")
print(J)


# Step 2: print w1 (rounded to 2 decimal places) and J (rounded to 2 decimal places)
print("value of w1:")
print(round(w1,2))
print("value of J:")
print(round(J,2))


# run gradient descent for niterations
for i in range(niterations):
    
    # Step 3: calculate new value of w1
    w1 = w1 - alpha * calc_dJ_dw1(w1)
    
    
    # Step 4: calculate new value of J at new w1
    J = calc_J(w1)
    
    
    # Step 5: print w1 (rounded to 2 decimal places) and J (rounded to 2 decimal places)
#     print(f"Iteration {i+1}: w1={w1:.2f}, J={J:.2f}")
    print("Iteration {}, w1={}, J={}".format(i+1,round(w1,2),round(J,2)))
# Out:
# value of J:
# 32832.5
# value of w1:
# 60
# value of J:
# 32832.5
# Iteration 1, w1=180.45, J=15906.26
# Iteration 2, w1=102.16, J=8754.93
# Iteration 3, w1=153.05, J=5733.49
# Iteration 4, w1=119.97, J=4456.93
# Iteration 5, w1=141.47, J=3917.59
# Iteration 6, w1=127.49, J=3689.71
# Iteration 7, w1=136.58, J=3593.44
# Iteration 8, w1=130.67, J=3552.76
# Iteration 9, w1=134.51, J=3535.57
# Iteration 10, w1=132.02, J=3528.31
# Iteration 11, w1=133.64, J=3525.24
# Iteration 12, w1=132.58, J=3523.95
# Iteration 13, w1=133.27, J=3523.4
# Iteration 14, w1=132.82, J=3523.17
# Iteration 15, w1=133.11, J=3523.07
# Iteration 16, w1=132.93, J=3523.03
# Iteration 17, w1=133.05, J=3523.01
# Iteration 18, w1=132.97, J=3523.01
# Iteration 19, w1=133.02, J=3523.0
# Iteration 20, w1=132.99, J=3523.0
# Iteration 21, w1=133.01, J=3523.0
# Iteration 22, w1=132.99, J=3523.0
# Iteration 23, w1=133.0, J=3523.0
# Iteration 24, w1=133.0, J=3523.0
# Iteration 25, w1=133.0, J=3523.0

# %%
# First, complete coding Steps 1 through 5 in this cell.
# Then, run this cell for each of the four scenarios below,
# and log your responses for each scenario run in the next cell (Step 6)
# alpha=0.08; niterations = 25; w1 = 60 # Scenario 1
# alpha=0.05; niterations = 25; w1 = 60 # Scenario 2
# alpha=0.15; niterations = 25; w1 = 60 # Scenario 3
alpha=0.19; niterations = 25; w1 = 60 # Scenario 4

# Step 1: calculate current value of J at current value of w1
J = calc_J(60)
print("value of J:")
print(J)


# Step 2: print w1 (rounded to 2 decimal places) and J (rounded to 2 decimal places)
print("value of w1:")
print(round(w1,2))
print("value of J:")
print(round(J,2))


# run gradient descent for niterations
for i in range(niterations):
    
    # Step 3: calculate new value of w1
    w1 = w1 - alpha * calc_dJ_dw1(w1)
    
    
    # Step 4: calculate new value of J at new w1
    J = calc_J(w1)
    
    
    # Step 5: print w1 (rounded to 2 decimal places) and J (rounded to 2 decimal places)
#     print(f"Iteration {i+1}: w1={w1:.2f}, J={J:.2f}")
    print("Iteration {}, w1={}, J={}".format(i+1,round(w1,2),round(J,2)))
# Out:
# value of J:
# 32832.5
# value of w1:
# 60
# value of J:
# 32832.5
# Iteration 1, w1=212.57, J=38345.62
# Iteration 2, w1=46.27, J=44895.75
# Iteration 3, w1=227.54, J=52677.97
# Iteration 4, w1=29.95, J=61924.01
# Iteration 5, w1=245.32, J=72909.25
# Iteration 6, w1=10.57, J=85960.8
# Iteration 7, w1=266.45, J=101467.35
# Iteration 8, w1=-12.46, J=119890.68
# Iteration 9, w1=291.55, J=141779.44
# Iteration 10, w1=-39.82, J=167785.48
# Iteration 11, w1=321.37, J=198683.25
# Iteration 12, w1=-72.32, J=235392.89
# Iteration 13, w1=356.8, J=279007.62
# Iteration 14, w1=-110.95, J=330826.28
# Iteration 15, w1=398.9, J=392392.02
# Iteration 16, w1=-156.83, J=465538.29
# Iteration 17, w1=448.92, J=552443.36
# Iteration 18, w1=-211.35, J=655695.28
# Iteration 19, w1=508.34, J=778368.89
# Iteration 20, w1=-276.12, J=924117.4
# Iteration 21, w1=578.94, J=1097281.2
# Iteration 22, w1=-353.08, J=1303017.12
# Iteration 23, w1=662.82, J=1547451.97
# Iteration 24, w1=-444.51, J=1837865.0
# ...

# %%
# Step 6: for each Scenario, answer the following questions based on the output
# type your answers below for each question
#
### Scenario 1 (alpha=0.08; niterations = 25; w1 = 60):
# did the cost steadily decrease as training progressed? 
Ans) The cost decreased gradually till iteration 4, from then on it is constant.
# did the gradient descent algorithm converge? 
Ans) Yes it did.
# what is the minimum cost?
Ans) The minimum cost is 3523.0.
# what is the optimal value of w1? 
Ans) The optimal value of w1 is 133.0
# in how many iterations did gradient descent converge (at which row # in the output)? 
Ans) The gradient descent converged at iteration 4.
#
### Scenario 2 (alpha=0.05; niterations = 25; w1 = 60):
# did the cost steadily decrease as training progressed? 
Ans) The cost decreased drastically from iteration 1 to 2 and from 2 to 3, then it gradually reduced till iteration 10, from then on it is constant.
# did the gradient descent algorithm converge? 
Ans) Yes it did.
# what is the minimum cost? 
Ans) The minimum cost is 3523.0.
# what is the optimal value of w1? 
Ans) The optimal value of w1 is 133.
# in how many iterations did gradient descent converge (at which row # in the output)? 
Ans) The gradient descent converged at iteration 10.
#
### Scenario 3 (alpha=0.15; niterations = 25; w1 = 60):
# did the cost steadily decrease as training progressed? 
Ans) The cost decreased drastically from iteration 1 to 2 and from 2 to 3 and from 3 to 4, then it gradually reduced till iteration 19, from then on it is constant.
# did the gradient descent algorithm converge? 
Ans) Yes it did
# what is the minimum cost? 
Ans) The minimum cost is 3523.0
# what is the optimal value of w1? 
Ans) The optimal value of w1 is 133.02
# in how many iterations did gradient descent converge (at which row # in the output)? 
Ans) The gradient descent converged at iteration 19
#
### Scenario 4 (alpha=0.19; niterations = 25; w1 = 60):
# did the cost steadily decrease as training progressed? 
Ans) The cost increased as the training progressed, it did not decrease.
# did the gradient descent algorithm converge? 
Ans) No it did not converge.
# what is the minimum cost?
Ans) 32832.5
# what is the optimal value of w1? 
Ans) There is no optimal value for w1.
# in how many iterations did gradient descent converge (at which row # in the output)?
Ans) The gradient descent did not converge.
